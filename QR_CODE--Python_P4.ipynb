# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import qrcode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\HP\Downloads\QR_CODE .ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/QR_CODE%20.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import qrcode
#
# ModuleNotFoundError: No module named 'qrcode'

# %%
#saving the link in variable
data=input("Please paste the link over here::")
# Out:
# Please paste the link over here:: https://www.internships.com/posting/lit_39566269160

# %%
#filename
file_name="OR_code_is_here.png"

# %%
#.make func is used to make the qrcode out of link
image=qrcode.make(data)
#.save func is used to save the qr code
image.save(file_name)
plt.imshow(image)
